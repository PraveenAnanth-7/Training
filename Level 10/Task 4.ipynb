# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)
df = housing.frame

corr_value = df['MedInc'].corr(df['MedHouseVal'])

print("Pearson Correlation between Income and House Value:", round(corr_value, 4))

plt.figure(figsize=(8, 5))
sns.scatterplot(x='MedInc', y='MedHouseVal', data=df, color='teal')
plt.title('Income vs House Value')
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.tight_layout()
plt.show()
# Out:
# Pearson Correlation between Income and House Value: 0.6881
