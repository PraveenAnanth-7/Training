# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

digits = load_digits()
X = digits.data
y = digits.target

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_scaled)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=y, cmap='tab10', s=60, edgecolor='k')
legend = ax.legend(*scatter.legend_elements(), title="Digits")
ax.add_artist(legend)
plt.title("3D PCA Projection")
plt.show()

print("Cumulative explained variance ratio:", np.cumsum(pca.explained_variance_ratio_))
# Out:
# Cumulative explained variance ratio: [0.12033916 0.21594971 0.30039385]
