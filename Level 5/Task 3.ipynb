# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("titanic")
summary_stats = df[['age', 'fare']].describe()
print("=== Titanic Dataset Summary Statistics ===")
print(summary_stats)
survival_rates = df.groupby("class")["survived"].mean()
# Out:
# === Titanic Dataset Summary Statistics ===
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200
# C:\Users\PRAVEEN ANANTH\AppData\Local\Temp\ipykernel_16268\2086763575.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rates = df.groupby("class")["survived"].mean()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=survival_rates.index, y=survival_rates.values, palette="coolwarm")
plt.title("Survival Rates by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.ylim(0, 1)
plt.show()
# Out:
# C:\Users\PRAVEEN ANANTH\AppData\Local\Temp\ipykernel_16268\3797098223.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rates.index, y=survival_rates.values, palette="coolwarm")
