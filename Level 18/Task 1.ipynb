# %%
# !pip install zenml[server]==0.81.0
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 1.4 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.0 MB 1.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.0/4.0 MB 1.3 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.3 MB/s eta 0:00:03
#    --------------- ------------------------ 1.6/4.0 MB 1.3 MB/s eta 0:00:02
#    ------------------ --------------------- 1.8/4.0 MB 1.2 MB/s eta 0:00:02
#    -------------------- ------------------- 2.1/4.0 MB 1.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.4/4.0 MB 1.2 MB/s eta 0:00:02
#    -------------------------- ------------- 2.6/4.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 1.2 MB/s eta 0:00:01
# ...

# %%
# !zenml init
# !zenml up
# Out:
# Migrating the ZenML global configuration from version 0.80.2 to version 0.81.0...
# ⠋ Initializing ZenML repository at c:\Users\PRAVEEN
# ANANTH\OneDrive\Desktop\Biriyani\Training\Level 18.
#
# ⠙ Initializing ZenML repository at c:\Users\PRAVEEN
# ANANTH\OneDrive\Desktop\Biriyani\Training\Level 18.
#
# ⠸ Initializing ZenML repository at c:\Users\PRAVEEN
# ANANTH\OneDrive\Desktop\Biriyani\Training\Level 18.
#
# ⠼ Initializing ZenML repository at c:\Users\PRAVEEN
# ANANTH\OneDrive\Desktop\Biriyani\Training\Level 18.
#
# ⠴ Initializing ZenML repository at c:\Users\PRAVEEN
# ANANTH\OneDrive\Desktop\Biriyani\Training\Level 18.
#
# ⠦ Initializing ZenML repository at c:\Users\PRAVEEN
# ANANTH\OneDrive\Desktop\Biriyani\Training\Level 18.
#
# ⠧ Initializing ZenML repository at c:\Users\PRAVEEN
# ANANTH\OneDrive\Desktop\Biriyani\Training\Level 18.
#
# ⠇ Initializing ZenML repository at c:\Users\PRAVEEN
# ANANTH\OneDrive\Desktop\Biriyani\Training\Level 18.
#
# ...
